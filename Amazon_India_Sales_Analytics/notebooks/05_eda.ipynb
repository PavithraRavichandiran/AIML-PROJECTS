# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# Load the cleaned dataset
df_clean = pd.read_csv('../data/cleaned/amazon_india_all_years_cleaned.csv')

print("="*80)
print("DATA QUALITY VERIFICATION - FINAL CHECK")
print("="*80)

print("\n1. DATASET INFO (VERIFICATION)")
print("-"*80)
df_clean.info()

print("\n2. STATISTICAL SUMMARY (VERIFICATION)")
print("-"*80)
print(df_clean.describe())

print("\n3. MISSING VALUES (VERIFICATION)")
print("-"*80)
print("Missing values count:")
print(df_clean.isnull().sum())

print("\n" + "="*80)
print("DATA QUALITY SUMMARY")
print("="*80)
print(f"Total Records: {len(df_clean):,}")
print(f"Total Columns: {len(df_clean.columns)}")
print(f"Total Missing Values: {df_clean.isnull().sum().sum():,}")
print(f"Data Integrity: {'✓ PASSED' if df_clean.isnull().sum().sum() == 0 else '⚠ REVIEW NEEDED'}")
print("="*80)
# Out:
# ...
# DATA QUALITY VERIFICATION - FINAL CHECK
# ...
#
# 1. DATASET INFO (VERIFICATION)
# --------------------------------------------------------------------------------
# <class 'pandas.DataFrame'>
# RangeIndex: 1122687 entries, 0 to 1122686
# Data columns (total 51 columns):
#  #   Column                                        Non-Null Count    Dtype
# ---  ------                                        --------------    -----
#  0   transaction_id                                1122687 non-null  str
#  1   order_date                                    1122687 non-null  str
#  2   customer_id                                   1122687 non-null  str
#  3   product_id                                    1122687 non-null  str
#  4   product_name                                  1122687 non-null  str
#  5   category                                      1122687 non-null  str
#  6   subcategory                                   1122687 non-null  str
# ...

# %% [markdown]
# ## Step 5: Data Quality Verification
# Re-run all validation checks to verify data quality and ensure no integrity issues exist in the cleaned dataset.

# %%
print("="*80)
print("MISSING VALUES COUNT")
print("="*80)
missing_values = df_clean.isnull().sum()
print(missing_values)

# Additional missing values analysis
print("\n" + "="*80)
print("MISSING VALUES PERCENTAGE")
print("="*80)
missing_percentage = (df_clean.isnull().sum() / len(df_clean)) * 100
print(missing_percentage)
# Out:
# ...
# MISSING VALUES COUNT
# ...
# transaction_id                                       0
# order_date                                           0
# customer_id                                          0
# product_id                                           0
# product_name                                         0
# category                                             0
# subcategory                                          0
# brand                                                0
# original_price_inr                               36422
# discount_percent                                     0
# discounted_price_inr                                 0
# quantity                                             0
# subtotal_inr                                         0
# delivery_charges                                 90201
# final_amount_inr                                     0
# customer_city                                        0
# customer_state                                       0
# ...

# %% [markdown]
# ## Step 4: Missing Values Analysis
# Identify and count missing values in each column of the dataset.

# %%
print("="*80)
print("STATISTICAL SUMMARY")
print("="*80)
print(df_clean.describe())
# Out:
# ...
# STATISTICAL SUMMARY
# ...
#        original_price_inr  discount_percent  discounted_price_inr  \
# count        1.086265e+06      1.122687e+06          1.122687e+06
# mean         8.325971e+04      1.742250e+01          5.453870e+04
# std          4.123913e+05      2.055422e+01          4.582234e+04
# min          1.067270e+03      0.000000e+00          3.443300e+02
# 25%          2.890007e+04      0.000000e+00          2.277949e+04
# 50%          4.662675e+04      1.037000e+01          3.799828e+04
# 75%          9.437859e+04      2.842000e+01          7.409729e+04
# max          3.337169e+07      7.000000e+01          4.207048e+05
#
#            quantity  subtotal_inr  delivery_charges  final_amount_inr  \
# count  1.122687e+06  1.122687e+06      1.032486e+06      1.122687e+06
# mean   1.250031e+00  6.818247e+04      3.099316e-04      6.818247e+04
# std    5.364616e-01  6.893156e+04      1.113426e-01      6.893156e+04
# ...

# %% [markdown]
# ## Step 3: Statistical Summary
# Generate descriptive statistics for numerical columns including count, mean, std, min, quartiles, and max values.

# %%
print("="*80)
print("DATASET INFORMATION")
print("="*80)
df_clean.info()
# Out:
# ...
# DATASET INFORMATION
# ...
# <class 'pandas.DataFrame'>
# RangeIndex: 1122687 entries, 0 to 1122686
# Data columns (total 51 columns):
#  #   Column                                        Non-Null Count    Dtype
# ---  ------                                        --------------    -----
#  0   transaction_id                                1122687 non-null  str
#  1   order_date                                    1122687 non-null  str
#  2   customer_id                                   1122687 non-null  str
#  3   product_id                                    1122687 non-null  str
#  4   product_name                                  1122687 non-null  str
#  5   category                                      1122687 non-null  str
#  6   subcategory                                   1122687 non-null  str
#  7   brand                                         1122687 non-null  str
#  8   original_price_inr                            1086265 non-null  float64
# ...

# %% [markdown]
# ## Step 2: Dataset Information Check
# Examine the dataset structure, column names, data types, non-null counts, and memory usage.

# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# Load the cleaned dataset
df_clean = pd.read_csv('../data/cleaned/amazon_india_all_years_cleaned.csv')

print("Dataset loaded successfully!")
print(f"Dataset shape: {df_clean.shape}")
print(f"Total rows: {df_clean.shape[0]:,}")
print(f"Total columns: {df_clean.shape[1]}")
# Out:
# Dataset loaded successfully!
# Dataset shape: (1122687, 51)
# Total rows: 1,122,687
# Total columns: 51

# %% [markdown]
# ## Step 1: Load the Dataset

# %% [markdown]
# # EDA - Step 1: Dataset Health Validation
# ## Exploratory Data Analysis for Amazon India Sales
#
# This notebook performs comprehensive exploratory data analysis with focus on dataset health validation.

# %% [markdown]
# # EDA - Step 1: Dataset Health Validation
# ## Exploratory Data Analysis for Amazon India Sales
#
# This notebook performs comprehensive exploratory data analysis with focus on dataset health validation.

# %% [markdown]
# ## Step 1: Load the Dataset
# Import necessary libraries and load the cleaned dataset for validation.

# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# Load the cleaned dataset
df_clean = pd.read_csv('../data/cleaned/amazon_india_all_years_cleaned.csv')

print("Dataset loaded successfully!")
print(f"Dataset shape: {df_clean.shape}")
print(f"Total rows: {df_clean.shape[0]:,}")
print(f"Total columns: {df_clean.shape[1]}")
# Out:
# Dataset loaded successfully!
# Dataset shape: (1122687, 51)
# Total rows: 1,122,687
# Total columns: 51

# %% [markdown]
# ## Step 2: Dataset Information Check
# Examine the dataset structure, column names, data types, non-null counts, and memory usage.

# %%
print("="*80)
print("DATASET INFORMATION")
print("="*80)
df_clean.info()
# Out:
# ...
# DATASET INFORMATION
# ...
# <class 'pandas.DataFrame'>
# RangeIndex: 1122687 entries, 0 to 1122686
# Data columns (total 51 columns):
#  #   Column                                        Non-Null Count    Dtype
# ---  ------                                        --------------    -----
#  0   transaction_id                                1122687 non-null  str
#  1   order_date                                    1122687 non-null  str
#  2   customer_id                                   1122687 non-null  str
#  3   product_id                                    1122687 non-null  str
#  4   product_name                                  1122687 non-null  str
#  5   category                                      1122687 non-null  str
#  6   subcategory                                   1122687 non-null  str
#  7   brand                                         1122687 non-null  str
#  8   original_price_inr                            1086265 non-null  float64
# ...

# %% [markdown]
# ## Step 3: Statistical Summary
# Generate descriptive statistics for numerical columns including count, mean, std, min, quartiles, and max values.

# %%
print("="*80)
print("STATISTICAL SUMMARY")
print("="*80)
print(df_clean.describe())
# Out:
# ...
# STATISTICAL SUMMARY
# ...
#        original_price_inr  discount_percent  discounted_price_inr  \
# count        1.086265e+06      1.122687e+06          1.122687e+06
# mean         8.325971e+04      1.742250e+01          5.453870e+04
# std          4.123913e+05      2.055422e+01          4.582234e+04
# min          1.067270e+03      0.000000e+00          3.443300e+02
# 25%          2.890007e+04      0.000000e+00          2.277949e+04
# 50%          4.662675e+04      1.037000e+01          3.799828e+04
# 75%          9.437859e+04      2.842000e+01          7.409729e+04
# max          3.337169e+07      7.000000e+01          4.207048e+05
#
#            quantity  subtotal_inr  delivery_charges  final_amount_inr  \
# count  1.122687e+06  1.122687e+06      1.032486e+06      1.122687e+06
# mean   1.250031e+00  6.818247e+04      3.099316e-04      6.818247e+04
# std    5.364616e-01  6.893156e+04      1.113426e-01      6.893156e+04
# ...

# %% [markdown]
# ## Step 4: Missing Values Analysis
# Identify and count missing values in each column of the dataset.

# %%
print("="*80)
print("MISSING VALUES COUNT")
print("="*80)
missing_values = df_clean.isnull().sum()
print(missing_values)

# Additional missing values analysis
print("\n" + "="*80)
print("MISSING VALUES PERCENTAGE")
print("="*80)
missing_percentage = (df_clean.isnull().sum() / len(df_clean)) * 100
print(missing_percentage)
# Out:
# ...
# MISSING VALUES COUNT
# ...
# transaction_id                                       0
# order_date                                           0
# customer_id                                          0
# product_id                                           0
# product_name                                         0
# category                                             0
# subcategory                                          0
# brand                                                0
# original_price_inr                               36422
# discount_percent                                     0
# discounted_price_inr                                 0
# quantity                                             0
# subtotal_inr                                         0
# delivery_charges                                 90201
# final_amount_inr                                     0
# customer_city                                        0
# customer_state                                       0
# ...

# %% [markdown]
# ## Step 5: Data Quality Verification
# Re-run all validation checks to verify data quality and ensure no integrity issues exist in the cleaned dataset.

# %%
print("="*80)
print("DATA QUALITY VERIFICATION - FINAL CHECK")
print("="*80)

print("\n1. DATASET INFO (VERIFICATION)")
print("-"*80)
df_clean.info()

print("\n2. STATISTICAL SUMMARY (VERIFICATION)")
print("-"*80)
print(df_clean.describe())

print("\n3. MISSING VALUES (VERIFICATION)")
print("-"*80)
print("Missing values count:")
print(df_clean.isnull().sum())

print("\n" + "="*80)
print("DATA QUALITY SUMMARY")
print("="*80)
print(f"Total Records: {len(df_clean):,}")
print(f"Total Columns: {len(df_clean.columns)}")
print(f"Total Missing Values: {df_clean.isnull().sum().sum():,}")
print(f"Data Integrity: {'✓ PASSED' if df_clean.isnull().sum().sum() == 0 else '⚠ REVIEW NEEDED'}")
print("="*80)
# Out:
# ...
# DATA QUALITY VERIFICATION - FINAL CHECK
# ...
#
# 1. DATASET INFO (VERIFICATION)
# --------------------------------------------------------------------------------
# <class 'pandas.DataFrame'>
# RangeIndex: 1122687 entries, 0 to 1122686
# Data columns (total 51 columns):
#  #   Column                                        Non-Null Count    Dtype
# ---  ------                                        --------------    -----
#  0   transaction_id                                1122687 non-null  str
#  1   order_date                                    1122687 non-null  str
#  2   customer_id                                   1122687 non-null  str
#  3   product_id                                    1122687 non-null  str
#  4   product_name                                  1122687 non-null  str
#  5   category                                      1122687 non-null  str
#  6   subcategory                                   1122687 non-null  str
# ...
